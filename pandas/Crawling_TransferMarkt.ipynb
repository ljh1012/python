# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
# headers에 'User-Agent' 값 넣기
headers = {'User-Agent' : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}

# url에 주소 넣기
url = "https://www.transfermarkt.com/"

# requests.get()으로 요청하기
r = requests.get(url, headers=headers)
# status_code 응답확인하기
r.status_code
# Out:
# 200

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
headers = {'User-Agent' : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
player_list=[]

# %%
i = 1
url = f'https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop?&ajax=yw1&page={i}'
r = requests.get(url, headers=headers)
print(f'status code (200은정상) : {r.status_code}')
soup = BeautifulSoup(r.text,'html.parser')
# Out:
# status code (200은정상) : 200

# %%
players = soup.find_all('tr', class_=['odd','even'])
for player in players:
    info = player.find_all('td')
    number = info[0].text
    name = info[3].text
    position = info[4].text
    age = info[5].text
    
    nations = info[6].find_all('img')
    nation_text = ""
    count = 0
    for nation in nations:
        sep = "," if count > 0 else ""
        nation_text += sep
        nation_text +=  nation.get('alt')
        count += 1
    nation = nation_text
    
    team = info[7].img['alt']
    value = info[8].text.strip()
    player_list.append([number, name, position, age, nation, team, value])
time.sleep(1)

df = pd.DataFrame(player_list, columns=['number', 'name', 'position', 'age', 'nation', 'team', 'value'])
df
# Out:
#    number                 name            position age           nation  \
# 0       1      Jude Bellingham  Attacking Midfield  20  England,Ireland
# 1       2       Erling Haaland      Centre-Forward  23           Norway
# 2       3        Kylian Mbappé      Centre-Forward  25  France,Cameroon
# 3       4      Vinicius Junior         Left Winger  23     Brazil,Spain
# 4       5          Bukayo Saka        Right Winger  22  England,Nigeria
# 5       6           Phil Foden        Right Winger  23          England
# 6       7        Jamal Musiala  Attacking Midfield  21  Germany,England
# 7       8     Lautaro Martínez      Centre-Forward  26        Argentina
# 8       9       Victor Osimhen      Centre-Forward  25          Nigeria
# 9      10          Declan Rice  Defensive Midfield  25  England,Ireland
# 10     11                Rodri  Defensive Midfield  27            Spain
# 11     12           Harry Kane      Centre-Forward  30          England
# ...

# %%
players1 = soup.find('tr', class_=['odd','even'])
players1
# Out:
# <tr class="odd">
# ...

# %%
info = players1.find_all('td')

number = info[0].text
name = info[3].text
position = info[4].text
age = info[5].text
nations = info[6].find_all('img')
nation_text = ""
count = 0
for nation in nations:
    sep = "," if count > 0 else ""
    nation_text += sep
    nation_text +=  nation.get('alt')
    count += 1
nation = nation_text

team = info[7].img['alt']
value = info[8].text.strip()

print(number, name, position, age, nation, team, value)
# Out:
# 1 Jude Bellingham Attacking Midfield 20 England,Ireland Real Madrid €180.00m

# %%
players2 = soup.find('tr', class_='even')
info = players2.find_all('td')

number = info[0].text
name = info[3].text
position = info[4].text
age = info[5].text
nations = info[6].find_all('img')
nation_text = ""
count = 0
for nation in nations:
    sep = "," if count > 0 else ""
    nation_text += sep
    nation_text +=  nation.get('alt')
    count += 1
nation = nation_text

team = info[7].img['alt']
value = info[8].text.strip()

print(number, name, position, age, nation, team, value)
# Out:
# 2 Erling Haaland Centre-Forward 23 Norway Manchester City €180.00m

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
headers = {'User-Agent' : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
player_list=[]

page = 2
for i in range(1,page+1):
    url = f'https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop?&ajax=yw1&page={i}'
    r = requests.get(url, headers=headers)
    if r.status_code != 200:
        print("Error Occured")
        break
    #     print(f'status code (200은정상) : {r.status_code}')
    soup = BeautifulSoup(r.text,'html.parser')

    players = soup.find_all('tr', class_=['odd','even'])
    for player in players:
        info = player.find_all('td')
        number = info[0].text
        name = info[3].text
        position = info[4].text
        age = info[5].text

        nations = info[6].find_all('img')
        nation_text = ""
        count = 0
        for nation in nations:
            sep = "," if count > 0 else ""
            nation_text += sep
            nation_text +=  nation.get('alt')
            count += 1
        nation = nation_text

        team = info[7].img['alt']
        value = info[8].text.strip()
        player_list.append([number, name, position, age, nation, team, value])
    time.sleep(1)

df = pd.DataFrame(player_list, columns=['number', 'name', 'position', 'age', 'nation', 'team', 'value'])
df
# Out:
#    number                    name            position age  \
# 0       1         Jude Bellingham  Attacking Midfield  20
# 1       2          Erling Haaland      Centre-Forward  23
# 2       3           Kylian Mbappé      Centre-Forward  25
# 3       4         Vinicius Junior         Left Winger  23
# 4       5             Bukayo Saka        Right Winger  22
# 5       6              Phil Foden        Right Winger  23
# 6       7           Jamal Musiala  Attacking Midfield  21
# 7       8        Lautaro Martínez      Centre-Forward  26
# 8       9          Victor Osimhen      Centre-Forward  25
# 9      10             Declan Rice  Defensive Midfield  25
# 10     11                   Rodri  Defensive Midfield  27
# 11     12              Harry Kane      Centre-Forward  30
# 12     13           Florian Wirtz  Attacking Midfield  20
# 13     14                 Rodrygo        Right Winger  23
# 14     15       Federico Valverde    Central Midfield  25
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
headers = {'User-Agent' : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
player_list=[]

page = 2
for i in range(1,page+1):
    url = f'https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop/plus/ajax/yw1/ausrichtung/alle/spielerposition_id/alle/altersklasse/alle/jahrgang/0/land_id/0/kontinent_id/1/yt0/Show/0//page/{i}'
    r = requests.get(url, headers=headers)
    if r.status_code != 200:
        print("Error Occured")
        break
    #     print(f'status code (200은정상) : {r.status_code}')
    soup = BeautifulSoup(r.text,'html.parser')

    players = soup.find_all('tr', class_=['odd','even'])
    for player in players:
        info = player.find_all('td')
        number = info[0].text
        name = info[3].text
        position = info[4].text
        age = info[5].text

        nations = info[6].find_all('img')
        nation_text = ""
        count = 0
        for nation in nations:
            sep = "," if count > 0 else ""
            nation_text += sep
            nation_text +=  nation.get('alt')
            count += 1
        nation = nation_text

        team = info[7].img['alt']
        value = info[8].text.strip()
        player_list.append([number, name, position, age, nation, team, value])
    time.sleep(2)

df_asia = pd.DataFrame(player_list, columns=['number', 'name', 'position', 'age', 'nation', 'team', 'value'])
df_asia
# Out:
#    number                 name            position age  \
# 0       1        Takefusa Kubo        Right Winger  22
# 1       2          Min-jae Kim         Centre-Back  27
# 2       3        Heung-min Son         Left Winger  31
# 3       4         Kaoru Mitoma         Left Winger  26
# 4       5    Takehiro Tomiyasu          Right-Back  25
# 5       6       Hee-chan Hwang      Centre-Forward  28
# 6       7           Hiroki Ito         Centre-Back  24
# 7       8          Kang-in Lee  Attacking Midfield  23
# 8       9           Ritsu Doan        Right Winger  25
# 9      10      Takumi Minamino         Left Winger  29
# 10     11           Ko Itakura         Centre-Back  27
# 11     12        Daichi Kamada  Attacking Midfield  27
# 12     13      Kyogo Furuhashi      Centre-Forward  29
# 13     14       Mahmoud Dahoud    Central Midfield  28
# 14     15          Wataru Endo  Defensive Midfield  31
# 15     16      Hidemasa Morita    Central Midfield  28
# ...

# %%
df_asia[df_asia['nation']=='Korea, South']
# Out:
#    number             name            position age        nation  \
# 1       2      Min-jae Kim         Centre-Back  27  Korea, South
# 2       3    Heung-min Son         Left Winger  31  Korea, South
# 5       6   Hee-chan Hwang      Centre-Forward  28  Korea, South
# 7       8      Kang-in Lee  Attacking Midfield  23  Korea, South
# 24     25   Hyun-seok Hong    Central Midfield  24  Korea, South
# 29     30    In-beom Hwang    Central Midfield  27  Korea, South
# 44     45  Woo-yeong Jeong  Attacking Midfield  24  Korea, South
# 45     46     Gue-sung Cho      Centre-Forward  26  Korea, South
#
#                        team    value
# 1             Bayern Munich  €60.00m
# 2         Tottenham Hotspur  €50.00m
# 5   Wolverhampton Wanderers  €25.00m
# 7       Paris Saint-Germain  €22.00m
# 24                 KAA Gent   €8.00m
# 29        Red Star Belgrade   €6.00m
# 44            VfB Stuttgart   €3.50m
# 45           FC Midtjylland   €3.50m

# %%
target_nation = 'Japan'
df_asia[df_asia['nation']==target_nation]
# Out:
#    number               name            position age nation  \
# 0       1      Takefusa Kubo        Right Winger  22  Japan
# 3       4       Kaoru Mitoma         Left Winger  26  Japan
# 4       5  Takehiro Tomiyasu          Right-Back  25  Japan
# 6       7         Hiroki Ito         Centre-Back  24  Japan
# 8       9         Ritsu Doan        Right Winger  25  Japan
# 9      10    Takumi Minamino         Left Winger  29  Japan
# 10     11         Ko Itakura         Centre-Back  27  Japan
# 11     12      Daichi Kamada  Attacking Midfield  27  Japan
# 12     13    Kyogo Furuhashi      Centre-Forward  29  Japan
# 14     15        Wataru Endo  Defensive Midfield  31  Japan
# 15     16    Hidemasa Morita    Central Midfield  28  Japan
# 16     17  Yukinari Sugawara          Right-Back  23  Japan
# 19     20          Junya Ito        Right Winger  31  Japan
# 20     21     Keito Nakamura         Left Winger  23  Japan
# 21     22         Reo Hatate    Central Midfield  26  Japan
# ...

# %% [markdown]
# ### AFC 소속 이적료 최상위 50명의 국적 알아보기

# %% [markdown]
# #### 이중 국적자가  있어 'Korea, South' 를 'South Korea'로 변경

# %%
df_asia['nation'] = df_asia['nation'].replace('Korea, South', 'South Korea')
df_asia['nation'].unique()
# Out:
# array(['Japan', 'South Korea', 'Syria,Germany', 'Iran',
#        'Australia,Scotland', 'Jordan', 'Qatar,Tanzania',
#        'United Arab Emirates,Brazil', 'Uzbekistan', 'Syria',
#        'United Arab Emirates,Argentina', 'Saudi Arabia', 'Australia',
#        'Australia,Italy', 'Indonesia,Netherlands'], dtype=object)

# %%
nations = list(df_asia['nation'].unique())
nations
# Out:
# ['Japan',
#  'South Korea',
#  'Syria,Germany',
#  'Iran',
#  'Australia,Scotland',
#  'Jordan',
#  'Qatar,Tanzania',
#  'United Arab Emirates,Brazil',
#  'Uzbekistan',
#  'Syria',
#  'United Arab Emirates,Argentina',
#  'Saudi Arabia',
#  'Australia',
#  'Australia,Italy',
#  'Indonesia,Netherlands']

# %%
for nation in nations:
    print(f'number of "{nation}" players : {df_asia["nation"].str.contains(nation, case=False).sum()}') # 문자열을 포함할때
#     print(f'number of "{nation}" players : {len(df_asia[df_asia["nation"]==nation])}')  # 일치할때
# Out:
# number of "Japan" players : 22
# number of "South Korea" players : 8
# number of "Syria,Germany" players : 1
# number of "Iran" players : 3
# number of "Australia,Scotland" players : 2
# number of "Jordan" players : 1
# number of "Qatar,Tanzania" players : 1
# number of "United Arab Emirates,Brazil" players : 3
# number of "Uzbekistan" players : 3
# number of "Syria" players : 2
# number of "United Arab Emirates,Argentina" players : 1
# number of "Saudi Arabia" players : 1
# number of "Australia" players : 4
# number of "Australia,Italy" players : 1
# number of "Indonesia,Netherlands" players : 1

# %% [markdown]
# ### AFC소속 국가를 찾기 위한 크롤링

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

headers = {'User-Agent' : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
url = "https://en.wikipedia.org/wiki/Asian_Football_Confederation"
r = requests.get(url, headers=headers)
r.status_code

soup = BeautifulSoup(r.text,'html.parser')

the_afc = []
# <tbody> 태그 찾기
tbody = soup.find(lambda tag: tag.name == 'tbody' and 'ASEAN Football Federation (AFF)' in tag.text)
tr_tags = tbody.find_all('tr')
for tr in tr_tags:
    a_tags = tr.select('td span a')
    for a in a_tags:
        the_afc.append(a.text)

print(len(the_afc))
the_afc
# Out:
# 47
# ['Australia',
#  'Brunei',
#  'Cambodia',
#  'Indonesia',
#  'Laos',
#  'Malaysia',
#  'Myanmar',
#  'Philippines',
#  'Singapore',
#  'Thailand',
#  'Timor-Leste',
#  'Vietnam',
#  'Afghanistan',
#  'Islamic Republic of Iran',
#  'Kyrgyz Republic',
#  'Tajikistan',
#  'Turkmenistan',
#  'Uzbekistan',
#  'China',
#  'Chinese Taipei',
#  'DPR Korea',
#  'Guam',
#  'Hong Kong, China',
#  'Japan',
#  'Korea Republic',
#  'Macau',
#  'Mongolia',
#  'Northern Mariana Islands',
#  'Bangladesh',
#  'Bhutan',
#  'India',
#  'Maldives',
#  'Nepal',
#  'Pakistan',
#  'Sri Lanka',
#  'Bahrain',
#  'Iraq',
#  'Jordan',
#  'Kuwait',
#  'Lebanon',
#  'Oman',
#  'Palestine',
#  'Qatar',
#  'Saudi Arabia',
#  'Syria',
#  'United Arab Emirates',
#  'Yemen']

# %% [markdown]
# #### 공식명칭을 약어로 수정 comma 제거

# %%
rename_list = {'Islamic Republic of Iran':'Iran', 'DPR Korea':'North Korea', 'Hong Kong, China':'Hong Kong', 'Korea Republic':'South Korea'}

for nation in rename_list.keys():
    if nation in the_afc:
        the_afc.remove(nation)
        the_afc.append(rename_list[nation])
print(len(the_afc))
the_afc
# Out:
# 47
# ['Australia',
#  'Brunei',
#  'Cambodia',
#  'Indonesia',
#  'Laos',
#  'Malaysia',
#  'Myanmar',
#  'Philippines',
#  'Singapore',
#  'Thailand',
#  'Timor-Leste',
#  'Vietnam',
#  'Afghanistan',
#  'Kyrgyz Republic',
#  'Tajikistan',
#  'Turkmenistan',
#  'Uzbekistan',
#  'China',
#  'Chinese Taipei',
#  'Guam',
#  'Japan',
#  'Macau',
#  'Mongolia',
#  'Northern Mariana Islands',
#  'Bangladesh',
#  'Bhutan',
#  'India',
#  'Maldives',
#  'Nepal',
#  'Pakistan',
#  'Sri Lanka',
#  'Bahrain',
#  'Iraq',
#  'Jordan',
#  'Kuwait',
#  'Lebanon',
#  'Oman',
#  'Palestine',
#  'Qatar',
#  'Saudi Arabia',
#  'Syria',
#  'United Arab Emirates',
#  'Yemen',
#  'Iran',
#  'North Korea',
#  'Hong Kong',
#  'South Korea']

# %%
rename_list = {'Islamic Republic of Iran':'Iran',  'DPR Korea':'North Korea', 'Hong Kong, China':'Hong Kong', 'Korea Republic':'South Korea'}

for nation_ in rename_list.keys():
    if nation_ in the_afc:
        the_afc.remove(nation_)
        the_afc.append(rename_list[nation_])

add_country=[]

for nation in nations:
    nation = nation.split(',') 
    for nation_name in nation:
        if (nation_name in the_afc) and (nation_name not in add_country):
            add_country.append(nation_name)
            print(f'"{nation_name}" players : {df_asia["nation"].str.contains(nation_name, case=False).sum()}')
# Out:
# "Japan" players : 22
# "South Korea" players : 8
# "Syria" players : 2
# "Iran" players : 3
# "Australia" players : 4
# "Jordan" players : 1
# "Qatar" players : 1
# "United Arab Emirates" players : 4
# "Uzbekistan" players : 3
# "Saudi Arabia" players : 1
# "Indonesia" players : 1
