# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
# headers에 'User-Agent' 값 넣기
headers = {'User-Agent' : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}

# url에 주소 넣기
url = "https://www.transfermarkt.com/"

# requests.get()으로 요청하기
r = requests.get(url, headers=headers)
# status_code 응답확인하기
r.status_code
# Out:
# 200

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
for i in 
    headers = {'User-Agent' : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
    player_list=[]
    i = 1
    url = f'https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop?&ajax=yw1&page={i}'
    r = requests.get(url, headers=headers)
    soup = BeautifulSoup(r.text,'html.parser')
    players = soup.find_all('tr', class_=['odd','even'])
    for player in players:
        info = player.find_all('td')
        number = info[0].text
        name = info[3].text
        position = info[4].text
        age = info[5].text
        nation = info[6].img['alt']
        team = info[7].img['alt']
        value = info[8].text.strip()
        player_list.append([number, name, position, age, nation, team, value])
    time.sleep(1)
# Out:
# status code (200은정상) : 200

# %%
# Out:
#    number                 name            position age     nation  \
# 0       1      Jude Bellingham  Attacking Midfield  20    England
# 1       2       Erling Haaland      Centre-Forward  23     Norway
# 2       3        Kylian Mbappé      Centre-Forward  25     France
# 3       4      Vinicius Junior         Left Winger  23     Brazil
# 4       5          Bukayo Saka        Right Winger  22    England
# 5       6           Phil Foden        Right Winger  23    England
# 6       7        Jamal Musiala  Attacking Midfield  21    Germany
# 7       8     Lautaro Martínez      Centre-Forward  26  Argentina
# 8       9       Victor Osimhen      Centre-Forward  25    Nigeria
# 9      10          Declan Rice  Defensive Midfield  25    England
# 10     11                Rodri  Defensive Midfield  27      Spain
# 11     12           Harry Kane      Centre-Forward  30    England
# 12     13        Florian Wirtz  Attacking Midfield  20    Germany
# 13     14              Rodrygo        Right Winger  23     Brazil
# 14     15    Federico Valverde    Central Midfield  25    Uruguay
# 15     16      Martin Ødegaard  Attacking Midfield  25     Norway
# 16     17                Pedri    Central Midfield  21      Spain
# 17     18                 Gavi    Central Midfield  19      Spain
# 18     19    Eduardo Camavinga    Central Midfield  21     France
# 19     20       Julián Álvarez      Second Striker  24  Argentina
# 20     21  Aurélien Tchouaméni  Defensive Midfield  24     France
# 21     22          Rafael Leão         Left Winger  24   Portugal
# 22     23      Bruno Guimarães  Defensive Midfield  26     Brazil
# 23     24       Moisés Caicedo  Defensive Midfield  22    Ecuador
# 24     25   Gabriel Martinelli         Left Winger  22     Brazil
#
#                    team     value
# 0           Real Madrid  €180.00m
# 1       Manchester City  €180.00m
# 2   Paris Saint-Germain  €180.00m
# 3           Real Madrid  €150.00m
# 4            Arsenal FC  €130.00m
# 5       Manchester City  €130.00m
# 6         Bayern Munich  €110.00m
# 7           Inter Milan  €110.00m
# 8            SSC Napoli  €110.00m
# 9            Arsenal FC  €110.00m
# 10      Manchester City  €110.00m
# 11        Bayern Munich  €110.00m
# 12  Bayer 04 Leverkusen  €100.00m
# 13          Real Madrid  €100.00m
# 14          Real Madrid  €100.00m
# 15           Arsenal FC   €95.00m
# 16         FC Barcelona   €90.00m
# 17         FC Barcelona   €90.00m
# 18          Real Madrid   €90.00m
# 19      Manchester City   €90.00m
# 20          Real Madrid   €90.00m
# 21             AC Milan   €90.00m
# 22     Newcastle United   €85.00m
# 23           Chelsea FC   €80.00m
# 24           Arsenal FC   €80.00m

# %%
df = pd.DataFrame(player_list, columns=['number', 'name', 'position', 'age', 'nation', 'team', 'value'])
df

# %%
players1 = soup.find('tr', class_=['odd','even'])
players1
# Out:
# <tr class="odd">
# <td class="zentriert">1</td><td class=""><table class="inline-table"><tr><td rowspan="2"><a href="#"><img alt="Jude Bellingham" class="bilderrahmen-fixed" src="https://img.a.transfermarkt.technology/portrait/small/581678-1693987944.jpg?lm=1" title="Jude Bellingham"/></a></td><td class="hauptlink"><a href="/jude-bellingham/profil/spieler/581678" title="Jude Bellingham">Jude Bellingham</a></td></tr><tr><td>Attacking Midfield</td></tr></table></td><td class="zentriert">20</td><td class="zentriert"><img alt="England" class="flaggenrahmen" src="https://tmssl.akamaized.net/images/flagge/verysmall/189.png?lm=1520611569" title="England"/><br/><img alt="Ireland" class="flaggenrahmen" src="https://tmssl.akamaized.net/images/flagge/verysmall/72.png?lm=1520611569" title="Ireland"/></td><td class="zentriert"><a href="/real-madrid/startseite/verein/418" title="Real Madrid"><img alt="Real Madrid" class="" src="https://tmssl.akamaized.net/images/wappen/verysmall/418.png?lm=1697726166" title="Real Madrid"/></a></td><td class="rechts hauptlink"><a href="/jude-bellingham/marktwertverlauf/spieler/581678">€180.00m</a> </td></tr>

# %%
info = players1.find_all('td')

number = info[0].text
name = info[3].text
position = info[4].text
age = info[5].text
nation = info[6].img['alt']
team = info[7].img['alt']
value = info[8].text.strip()
# nations = info[6].find_all('img')
# for nation in nations:
#     print(nation)

print(number, name, position, age, nation, team, value)
# Out:
# 1 Jude Bellingham Attacking Midfield 20 England Real Madrid €180.00m

# %%
players2 = soup.find('tr', class_='even')
info = players2.find_all('td')

number = info[0].text
name = info[3].text
position = info[4].text
age = info[5].text
nation = info[6].img['alt']
team = info[7].img['alt']
value = info[8].text.strip()

print(number, name, position, age, nation, team, value)
# Out:
# 2 Erling Haaland Centre-Forward 23 Norway Manchester City €180.00m

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
headers = {'User-Agent' : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
player_list=[]

i = 2
url = f'https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop?&ajax=yw1&page={i}'
r = requests.get(url, headers=headers)
print(f'status code (200은정상) : {r.status_code}')
soup = BeautifulSoup(r.text,'html.parser')

players = soup.find_all('tr', class_=['odd','even'])
for player in players:
    info = player.find_all('td')
    number = info[0].text
    name = info[3].text
    position = info[4].text
    age = info[5].text
    nation = info[6].img['alt']
    team = info[7].img['alt']
    value = info[8].text.strip()
    player_list.append([number, name, position, age, nation, team, value])
time.sleep(1)

df = pd.DataFrame(player_list, columns=['number', 'name', 'position', 'age', 'nation', 'team', 'value'])
df
# Out:
# status code (200은정상) : 200
#    number                    name            position age       nation  \
# 0      26          Enzo Fernández    Central Midfield  23    Argentina
# 1      27   Khvicha Kvaratskhelia         Left Winger  23      Georgia
# 2      28          William Saliba         Centre-Back  22       France
# 3      29         Frenkie de Jong    Central Midfield  26  Netherlands
# 4      30              Rúben Dias         Centre-Back  26     Portugal
# 5      31          Bernardo Silva  Attacking Midfield  29     Portugal
# 6      32              Leroy Sané        Right Winger  28      Germany
# 7      33               Luis Díaz         Left Winger  27     Colombia
# 8      34          Josko Gvardiol         Centre-Back  22      Croatia
# 9      35      Dominik Szoboszlai    Central Midfield  23      Hungary
# 10     36          Nicolò Barella    Central Midfield  27        Italy
# 11     37          Joshua Kimmich  Defensive Midfield  29      Germany
# 12     38             Xavi Simons  Attacking Midfield  20  Netherlands
# 13     39            Darwin Núñez      Centre-Forward  24      Uruguay
# 14     40     Alexis Mac Allister    Central Midfield  25    Argentina
# 15     41           Ronald Araujo         Centre-Back  25      Uruguay
# 16     42            Douglas Luiz    Central Midfield  25       Brazil
# 17     43         Alphonso Davies           Left-Back  23       Canada
# 18     44            Éder Militão         Centre-Back  26       Brazil
# 19     45           Gabriel Jesus      Centre-Forward  26       Brazil
# 20     46          Alexander Isak      Centre-Forward  24       Sweden
# 21     47      Christopher Nkunku  Attacking Midfield  26       France
# 22     48      Alessandro Bastoni         Centre-Back  24        Italy
# 23     49  Trent Alexander-Arnold          Right-Back  25      England
# 24     50          James Maddison  Attacking Midfield  27      England
#
#                  team    value
# 0          Chelsea FC  €80.00m
# 1          SSC Napoli  €80.00m
# 2          Arsenal FC  €80.00m
# 3        FC Barcelona  €80.00m
# 4     Manchester City  €80.00m
# 5     Manchester City  €80.00m
# 6       Bayern Munich  €80.00m
# 7        Liverpool FC  €75.00m
# 8     Manchester City  €75.00m
# 9        Liverpool FC  €75.00m
# 10        Inter Milan  €75.00m
# 11      Bayern Munich  €75.00m
# 12         RB Leipzig  €70.00m
# 13       Liverpool FC  €70.00m
# 14       Liverpool FC  €70.00m
# 15       FC Barcelona  €70.00m
# 16        Aston Villa  €70.00m
# 17      Bayern Munich  €70.00m
# 18        Real Madrid  €70.00m
# 19         Arsenal FC  €70.00m
# 20   Newcastle United  €70.00m
# 21         Chelsea FC  €70.00m
# 22        Inter Milan  €70.00m
# 23       Liverpool FC  €70.00m
# 24  Tottenham Hotspur  €70.00m
