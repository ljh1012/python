# %% [markdown]
# # 1. Crawling https://www.transfermarkt.com/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from bs4 import BeautifulSoup
import time
# %matplotlib inline

# %%
headers = {'User-Agent' : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}

player_list=[]
for i in range(1,5):
    url = f'https://www.transfermarkt.com/spieler-statistik/wertvollstespieler/marktwertetop/plus/ausrichtung/alle/spielerposition_id/alle/altersklasse/alle/jahrgang/0/land_id/0/kontinent_id/1/yt0/Show/0//page/{i}'
    r = requests.get(url, headers=headers)
    soup = BeautifulSoup(r.text,'html.parser')
    players = soup.find_all('tr', class_=['odd','even'])
    for player in players:
        info = player.find_all('td')
        value_rank = info[0].text
        name = info[3].text
        position = info[4].text
        nations = info[6].find_all('img')
        nation_text = ""
        count = 0
        for nation in nations:
            sep = "," if count > 0 else ""
            nation_text += sep
            nation_text +=  nation.get('alt')
            count += 1
        nation = nation_text
        value = info[8].text.strip()
        player_list.append([value_rank, name, position, nation, value])
    time.sleep(1)
    
    
# 1. 1)
df = pd.DataFrame(player_list, columns=['value_rank', 'name', 'position', 'nation', 'value'])
df.set_index('value_rank', inplace=True)
df
# Out:
#                          name            position                nation  \
# value_rank
# 1               Takefusa Kubo        Right Winger                 Japan
# 2                 Min-jae Kim         Centre-Back          Korea, South
# 3               Heung-min Son         Left Winger          Korea, South
# 4                Kaoru Mitoma         Left Winger                 Japan
# 5           Takehiro Tomiyasu          Right-Back                 Japan
# ...                       ...                 ...                   ...
# 96           Sadegh Moharrami          Right-Back                  Iran
# 97              Saman Ghoddos  Attacking Midfield           Iran,Sweden
# 98           Salem Al-Dawsari         Left Winger          Saudi Arabia
# 99            Gerrit Holtmann         Left Winger   Philippines,Germany
# 100              Ali Mabkhout      Centre-Forward  United Arab Emirates
#
#               value
# value_rank
# 1           €60.00m
# 2           €60.00m
# 3           €50.00m
# 4           €45.00m
# 5           €30.00m
# ...             ...
# 96           €2.00m
# 97           €2.00m
# 98           €2.00m
# 99           €2.00m
# 100          €2.00m
#
# [100 rows x 4 columns]

# %%
df_2 = df.copy()

# %%
# 1. 2) 상위 3명(head)
df_2.head(3)
# Out:
#                      name      position        nation    value
# value_rank
# 1           Takefusa Kubo  Right Winger         Japan  €60.00m
# 2             Min-jae Kim   Centre-Back  Korea, South  €60.00m
# 3           Heung-min Son   Left Winger  Korea, South  €50.00m

# %%
# 1. 2) 하위 3명(tail)
df_2.tail(3)
# Out:
#                         name        position                nation   value
# value_rank
# 98          Salem Al-Dawsari     Left Winger          Saudi Arabia  €2.00m
# 99           Gerrit Holtmann     Left Winger   Philippines,Germany  €2.00m
# 100             Ali Mabkhout  Centre-Forward  United Arab Emirates  €2.00m

# %%
countries =[]

url_country = 'https://en.wikipedia.org/wiki/Asian_Football_Confederation'
r_country = requests.get(url_country, headers=headers)
soup_country = BeautifulSoup(r_country.text,'html.parser')
country = soup_country.find(lambda tag: tag.name == 'table' and "FIFA Men's Rankings (as of 15 February 2024)" in tag.text)
countries_a = country.find_all('a')
for i, country_a in enumerate(countries_a):
    if i >= 1:
        countries.append(country_a.text) 

countries #  AFC 소속 국가
# Out:
# ['Japan',
#  'Iran',
#  'South Korea',
#  'Australia',
#  'Qatar',
#  'Saudi Arabia',
#  'Iraq',
#  'Uzbekistan',
#  'United Arab Emirates',
#  'Jordan',
#  'Oman',
#  'Bahrain',
#  'China',
#  'Syria',
#  'Palestine',
#  'Tajikistan',
#  'Thailand',
#  'Kyrgyzstan',
#  'Vietnam',
#  'North Korea',
#  'Lebanon',
#  'India',
#  'Malaysia',
#  'Kuwait',
#  'Philippines',
#  'Turkmenistan',
#  'Indonesia',
#  'Yemen',
#  'Chinese Taipei',
#  'Hong Kong',
#  'Singapore',
#  'Afghanistan',
#  'Maldives',
#  'Myanmar',
#  'Nepal',
#  'Cambodia',
#  'Bangladesh',
#  'Bhutan',
#  'Macau',
#  'Laos',
#  'Mongolia',
#  'Brunei',
#  'Pakistan',
#  'Timor-Leste',
#  'Sri Lanka',
#  'Guam']

# %%
def arrange_nations(x):
    x_split = x.split(',')
    for n in x_split:
        if not n in countries:
            pass
        elif n in countries:
            return n

# %%
df_2.loc[df_2['nation'] == 'Korea, South','nation'] = 'South Korea'
df_2['nations'] = df_2['nation'].apply(arrange_nations)
df_2['nations'].unique()
# Out:
# array(['Japan', 'South Korea', 'Syria', 'Iran', 'Australia', 'Jordan',
#        'Qatar', 'United Arab Emirates', 'Uzbekistan', 'Saudi Arabia',
#        'Indonesia', 'Bahrain', 'Philippines'], dtype=object)

# %%
# 1. 3) 이중국적 미분류

df_grouped = df_2.groupby('nation')
df_grouped['name'].count().plot.bar()
# Out:
# <Axes: xlabel='nation'>

# %%
# 1. 3) 이중국적 분류

df_grouped = df_2.groupby('nations')
df_grouped['name'].count().plot.bar()
# Out:
# <Axes: xlabel='nations'>

# %%
#1. 4) csv로 저장
df.to_csv('D:/python/pandas/data/afc_player_100.csv')

# %% [markdown]
# # 2. 소상공인시장진흥공단_상가(상권)정보_대구_202312.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_store = pd.read_csv('data/소상공인시장진흥공단_상가(상권)정보_대구_202312.csv', encoding='utf-8')
df_store
# Out:
#                       상가업소번호         상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA0101202210A0090318         아보카  NaN        I2       음식      I203
# 1       MA010120220805430943         모텔탑  NaN        I1       숙박      I101
# 2       MA010120220805432876        킴스헤어  NaN        S2    수리·개인      S207
# 3       MA010120220805435697     카페사람이야기  NaN        I2       음식      I212
# 4       MA010120220805435246         다즐링  NaN        I2       음식      I212
# ...                      ...         ...  ...       ...      ...       ...
# 113634  MA010120220809479663        공원식당  NaN        I2       음식      I201
# 113635  MA010120220808880885      컴퓨터 학원  NaN        P1       교육      P106
# 113636  MA010120220803068778       동성F&D  NaN        I2       음식      I210
# 113637  MA010120220809507658        수103  NaN        G2       소매      G209
# 113638  MA010120220805021978  이디야커피대구송현점  NaN        I2       음식      I212
#
#            상권업종중분류명 상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...  \
# 0                일식    I20301    일식 회/초밥   I56122  ...
# 1             일반 숙박    I10102      여관/모텔   I55102  ...
# 2             이용·미용    S20701        미용실   S96112  ...
# 3             비알코올     I21201         카페   I56221  ...
# 4             비알코올     I21201         카페   I56221  ...
# ...             ...       ...        ...      ...  ...
# 113634           한식    I20101     백반/한정식   I56111  ...
# 113635        기타 교육    P10627     컴퓨터 학원   P85691  ...
# 113636        기타 간이    I21003         피자   I56192  ...
# 113637  섬유·의복·신발 소매    G20902  여성 의류 소매업   G47412  ...
# 113638        비알코올     I21201         카페   I56221  ...
#
#                            건물관리번호       건물명                  도로명주소   구우편번호  \
# 0       2729011600110100000000001       NaN      대구광역시 달서구 수밭동길 34  704802
# 1       2714014200100370005004100       NaN    대구광역시 동구 파계로138길 40  701500
# 2       2723011400106790000009408  대구동서변그린빌        대구광역시 북구 동변로 55  702733
# 3       2714012300110990000000001       NaN  대구광역시 동구 이노밸리로46길 4-9  701290
# 4       2714010200103510034044815       NaN        대구광역시 동구 화랑로 23  701829
# ...                           ...       ...                    ...     ...
# 113634  2729012200119530035032165       NaN     대구광역시 달서구 송현로8길 18  704827
# 113635  2726010100113090000030761       NaN      대구광역시 수성구 들안로 393  706826
# 113636  2714010100106090014042494       NaN     대구광역시 동구 아양로11길 26  701819
# 113637  2729011800101100001009758       NaN     대구광역시 달서구 조암남로 166  704390
# 113638  2729012200106350000030948       NaN      대구광역시 달서구 월배로 379  704825
#
#         신우편번호  동정보  층정보  호정보          경도         위도
# 0       42835  NaN    1  NaN  128.549749  35.795445
# 1       41001  NaN  NaN  NaN  128.639751  35.992577
# 2       41414  NaN    1  NaN  128.602432  35.916799
# 3       41067  NaN    1  NaN  128.721839  35.877366
# 4       41252  NaN    1  NaN  128.631047  35.868657
# ...       ...  ...  ...  ...         ...        ...
# 113634  42825  NaN  NaN  NaN  128.549018  35.822606
# 113635  42001  NaN  NaN  NaN  128.617942  35.865192
# 113636  41194  NaN    1  NaN  128.621018  35.884834
# 113637  42761  NaN  NaN  NaN  128.516825  35.815970
# 113638  42741  NaN  NaN  NaN  128.549426  35.828769
#
# [113639 rows x 39 columns]

# %%
df_store.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
#2. 1) 필요없는 column 제거
df_store.drop(df_store.columns[df_store.columns.str.contains('코드')], axis = 1, inplace=True) # column 중 문자열에 '코드'를 포함하는 경우 drop
df_store.drop(['상가업소번호', '표준산업분류명','대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명', '건물본번지', '건물부번지', '건물관리번호', '건물명','구우편번호', '신우편번호', '동정보', '층정보', '호정보', ], axis=1, inplace=True) # 남은 column 제거
df_store.columns
# Out:
# Index(['상호명', '지점명', '상권업종대분류명', '상권업종중분류명', '상권업종소분류명', '시도명', '시군구명', '행정동명',
#        '법정동명', '도로명주소', '경도', '위도'],
#       dtype='object')

# %%
#2. 2) csv로 저장
df_store.to_csv('D:/python/pandas/data/daegu_store_info.csv')

# %% [markdown]
# # 3. 햄버거 프랜차이즈
#     2. df_store을 이어서 사용

# %%
df_burger = df_store.copy()
df_burger
# Out:
#                상호명  지점명 상권업종대분류명     상권업종중분류명   상권업종소분류명    시도명 시군구명   행정동명  \
# 0              아보카  NaN       음식           일식    일식 회/초밥  대구광역시  달서구    도원동
# 1              모텔탑  NaN       숙박        일반 숙박      여관/모텔  대구광역시   동구    공산동
# 2             킴스헤어  NaN    수리·개인        이용·미용        미용실  대구광역시   북구  무태조야동
# 3          카페사람이야기  NaN       음식        비알코올          카페  대구광역시   동구    혁신동
# 4              다즐링  NaN       음식        비알코올          카페  대구광역시   동구   신천4동
# ...            ...  ...      ...          ...        ...    ...  ...    ...
# 113634        공원식당  NaN       음식           한식     백반/한정식  대구광역시  달서구   송현1동
# 113635      컴퓨터 학원  NaN       교육        기타 교육     컴퓨터 학원  대구광역시  수성구   범어3동
# 113636       동성F&D  NaN       음식        기타 간이         피자  대구광역시   동구   신암1동
# 113637        수103  NaN       소매  섬유·의복·신발 소매  여성 의류 소매업  대구광역시  달서구    유천동
# 113638  이디야커피대구송현점  NaN       음식        비알코올          카페  대구광역시  달서구   송현2동
#
#        법정동명                  도로명주소          경도         위도
# 0       도원동      대구광역시 달서구 수밭동길 34  128.549749  35.795445
# 1       중대동    대구광역시 동구 파계로138길 40  128.639751  35.992577
# 2       동변동        대구광역시 북구 동변로 55  128.602432  35.916799
# 3       각산동  대구광역시 동구 이노밸리로46길 4-9  128.721839  35.877366
# 4       신천동        대구광역시 동구 화랑로 23  128.631047  35.868657
# ...     ...                    ...         ...        ...
# 113634  송현동     대구광역시 달서구 송현로8길 18  128.549018  35.822606
# 113635  범어동      대구광역시 수성구 들안로 393  128.617942  35.865192
# 113636  신암동     대구광역시 동구 아양로11길 26  128.621018  35.884834
# 113637  유천동     대구광역시 달서구 조암남로 166  128.516825  35.815970
# 113638  송현동      대구광역시 달서구 월배로 379  128.549426  35.828769
#
# [113639 rows x 12 columns]

# %%
key = '맥도날드|롯데리아|버거킹|맘스터치|노브랜드버거'
df_burger = df_burger.loc[df_burger['상호명'].str.contains(key)].copy() # 제시된 프랜차이즈만 걸러내기

translator = ['맥도날드','롯데리아','버거킹','맘스터치','노브랜드버거'] # column '브랜드명' 생성
for i, name in enumerate(translator):
    df_burger.loc[df_burger['상호명'].str.contains(name), '브랜드명'] = translator[i]
# 3. 1) 각 브래드별 지점수
df_burger['브랜드명'].value_counts()
# Out:
# 브랜드명
# 맘스터치      66
# 롯데리아      51
# 버거킹       21
# 노브랜드버거    11
# 맥도날드       6
# Name: count, dtype: int64

# %%
# 3. 2) 지점수 많은 순으로 정렬
for i in df_burger.index:
    df_burger.loc[i,'브랜드지점수'] = df_burger['브랜드명'].value_counts()[df_burger.loc[i,'브랜드명']]

df_burger_sorted = df_burger.sort_values(by='브랜드지점수', axis=0, ascending=False)
df_burger_sorted.head(3)
# Out:
#               상호명  지점명 상권업종대분류명 상권업종중분류명 상권업종소분류명    시도명 시군구명  행정동명 법정동명  \
# 59460     맘스터치두류점  NaN       음식    기타 간이       버거  대구광역시  달서구  두류3동  두류동
# 35715  맘스터치북부정류장점  NaN       음식    기타 간이       버거  대구광역시   서구  비산7동  비산동
# 25121        맘스터치  NaN       음식    기타 간이       버거  대구광역시  수성구    파동   파동
#
#                       도로명주소          경도         위도  브랜드명  브랜드지점수
# 59460  대구광역시 달서구 달구벌대로 1728  128.554532  35.856407  맘스터치    66.0
# 35715     대구광역시 서구 서대구로 304  128.557188  35.884705  맘스터치    66.0
# 25121     대구광역시 수성구 파동로 123  128.615468  35.814415  맘스터치    66.0

# %%
# 3. 3) 각 구별 브랜드 수


table_brand = df_burger_sorted.pivot_table(index="시군구명",columns='브랜드명',
                                values="상호명", aggfunc="count", fill_value=0)
table_brand
# Out:
# 브랜드명  노브랜드버거  롯데리아  맘스터치  맥도날드  버거킹
# 시군구명
# 군위군        0     0     1     0    0
# 남구         0     4     5     0    2
# 달서구        2     8    16     2    3
# 달성군        0     9     7     0    2
# 동구         4     5    10     0    3
# 북구         2     8    11     0    5
# 서구         0     4     3     2    1
# 수성구        2     8    11     1    3
# 중구         1     5     2     1    2

# %%
# 3. 4) bar
plt.rc('font', family="Malgun Gothic") # 한글폰트
color_dict = {'맥도날드':'#00C7FF',  '롯데리아':'#EE0613', '버거킹':'orange', '맘스터치':'green', '노브랜드버거':'violet'}
plt.figure(figsize=(15,4))
g = sns.countplot(data=df_burger_sorted, x="시군구명", hue='브랜드명', palette=color_dict)

# %%
# 3. 5) 지도
# 아나콘다 power shell에서 pip install folium
import folium

lat = df_burger_sorted['위도'].mean()
long = df_burger_sorted['경도'].mean()

m = folium.Map(location=[lat,long], zoom_start=12, height=800)

for i in df_burger.index:
    row = df_burger.loc[i]
    i_lat = row['위도']
    i_long = row['경도']
    label = row['브랜드명']+' - '+row['도로명주소'][6:] # 도로명 주소앞 '대구광역시 ' 생략
    color = color_dict[row['브랜드명']]
    popup = folium.Popup(label, max_width=150)
    folium.CircleMarker(
        location = [i_lat, i_long],
        radius = 10,
        color = color,
        fill = False,
        fill_opacity = 1, 
        fill_color = color,
        popup = popup
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ebc2f8ad062ce0fe69a0120ee3f33416 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 800.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ebc2f8ad062ce0fe69a0120ee3f33416&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ebc2f8ad062ce0fe69a0120ee3f33416 = L.map(
#                 &quot;map_ebc2f8ad062ce0fe69a0120ee3f33416&quot;,
#                 {
#                     center: [35.85787999859596, 128.58354190032745],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c8f13cd45b51baf2094d7676eb380bae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c8f13cd45b51baf2094d7676eb380bae.addTo(map_ebc2f8ad062ce0fe69a0120ee3f33416);
#
#
#             var circle_marker_20264e6ca363e87e1fde938bf1ad75b6 = L.circleMarker(
#                 [35.8173698745373, 128.538823144316],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;violet&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;violet&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ebc2f8ad062ce0fe69a0120ee3f33416);
#
#
#         var popup_2aa4b93684e2df77b4a742e92bc1e4ab = L.popup({&quot;maxWidth&quot;: 150});
#
#
#
#                 var html_3c3dbd6a1c57c0ddfd671a0875a44782 = $(`&lt;div id=&quot;html_3c3dbd6a1c57c0ddfd671a0875a44782&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;노브랜드버거 - 달서구 월곡로 257&lt;/div&gt;`)[0];
#                 popup_2aa4b93684e2df77b4a742e92bc1e4ab.setContent(html_3c3dbd6a1c57c0ddfd671a0875a44782);
#
#
#
#         circle_marker_20264e6ca363e87e1fde938bf1ad75b6.bindPopup(popup_2aa4b93684e2df77b4a742e92bc1e4ab)
#         ;
#
#
#
#
#             var circle_marker_7b96ea66b6d05bbdc935ed983346bad3 = L.circleMarker(
#                 [35.8614474197479, 128.544258916886],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#EE0613&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#EE0613&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ebc2f8ad062ce0fe69a0120ee3f33416);
#
#
#         var popup_c97774747e2803600c2241e383d67b99 = L.popup({&quot;maxWidth&quot;: 150});
#
#
#
#                 var html_33b920f92fcc3bead6b963adf588bdfb = $(`&lt;div id=&quot;html_33b920f92fcc3bead6b963adf588bdfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;롯데리아 - 서구 평리로35길 18-8&lt;/div&gt;`)[0];
#                 popup_c97774747e2803600c2241e383d67b99.setContent(html_33b920f92fcc3bead6b963adf588bdfb);
#
#
#
#         circle_marker_7b96ea66b6d05bbdc935ed983346bad3.bindPopup(popup_c97774747e2803600c2241e383d67b99)
#         ;
#
#
#
#
#             var circle_marker_05e8303f9da6c180f8c00e6efdb2e44d = L.circleMarker(
#                 [35.6556643636083, 128.419861876463],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ebc2f8ad062ce0fe69a0120ee3f33416);
#
#
#         var popup_4b077167e41e2599a5cf877f4e9ddaa9 = L.popup({&quot;maxWidth&quot;: 150});
#
#
#
#                 var html_f3bd01ad0f4038299fc7c8f9ec9fa777 = $(`&lt;div id=&quot;html_f3bd01ad0f4038299fc7c8f9ec9fa777&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;맘스터치 - 달성군 구지면 과학마을로 60&lt;/div&gt;`)[0];
#                 popup_4b077167e41e2599a5cf877f4e9ddaa9.setContent(html_f3bd01ad0f4038299fc7c8f9ec9fa777);
#
#
#
#         circle_marker_05e8303f9da6c180f8c00e6efdb2e44d.bindPopup(popup_4b077167e41e2599a5cf877f4e9ddaa9)
#         ;
#
#
#
#
#             var circle_marker_3d3df91649230daa9f27de5eb744bc8e = L.circleMarker(
#                 [35.8155168927392, 128.523694323615],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true,
